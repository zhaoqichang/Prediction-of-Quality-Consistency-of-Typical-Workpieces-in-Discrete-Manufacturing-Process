# %% [markdown]
# ## 大部分都是对于ppf的问题

# %% [markdown]
# https://github.com/pandas-profiling/pandas-profiling
#
# warnings不用管就对了
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import pandas_profiling as ppf

# %%
train_data = pd.read_csv("data/first_round_training_data.csv")

# %%
ppf.ProfileReport(train_data,)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# 1、内存溢出的问题。
#
# 我没有遇到过这种问题，我的电脑配置是i5、8G的独显，也许你们可以设置参数minmal=True

# %% [markdown]
# 2、关于生成的图表的理解
#
# 皮尔逊系数：要是相关性系数为0，就代表着不相关，若是为1或者-1，就代表着相关
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.斯皮尔曼图的理解
#
# 等级差的理解https://zhidao.baidu.com/question/142344627.html

# %% [markdown]
# 4、数据存在偏度
#
# 去偏：取对数、开方、cox-box

# %% [markdown]
# 5、特征工程的进行
#
# 结合背景知识
#
# 充分了解数据
#
# 数据科学技能

# %% [markdown]
# 6、传统的机器学习算法VS深度学习
#
# 传统机器学习算法无处不在
#
# 深度学习不见得有那么好（图像、文本、语音）

# %% [markdown]
# 7、图像数据的不均衡问题
#
# 数据一定要均衡
#
# 数据增强问题
#
# 数据去噪问题

# %% [markdown]
# 8、真实的项目中的数据收集问题
#
# 你要了解背景问题
#
# 数据的采集是需要专门的人去采集的

# %% [markdown]
# 9、数据（表格化数据）挖掘的一般流程与方法

# %% [markdown]
# 数据预处理：
#
# 异常数据数据处理
#
# 空值填充
#
# 数值类型转换
#
# 数据相关性分析
#
# 去偏、去噪、去峰
#
# 。。。。。。。。

# %% [markdown]
# 特征工程：
#
# 结合背景知识
#
# 完备的数据科学技能
#
# 对数据要敏感

# %% [markdown]
# 模型选型：
#
# 模型的大小（权衡）
#
# 速度（运行时间长短）训练
#
# 参数量要少
#
# 模型可视化界面要清楚

# %% [markdown]
# 模型部署：
